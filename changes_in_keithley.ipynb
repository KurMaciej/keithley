# %%
###UNCOMMENT
##IN first paragraph
# import Keithley 2400; address 24
#from pymeasure.instruments.keithley import Keithley2400
#import pyvisa

##IN def switch_measurement_mode(mode='voltage')
#rm = pyvisa.ResourceManager()
#keithley_pyvisa = rm.open_resource('GPIB::24::INSTR')
#keithley_pyvisa.write(':SENS:FUNC "VOLT"')
#keithley_pyvisa.write(':SENS:VOLT:RANG:AUTO ON')
#keithley_pyvisa.write(':SENS:FUNC "CURR"')
#keithley_pyvisa.write(':SENS:CURR:RANG:AUTO ON')

##IN def set_sense_mode(mode='4-wire sensing'):
#keithley.wires = 4
#keithley.wires = 2

##IN def start_measurement()
#configure_keithley('DC', compliance_current=compliance_current_value, set_voltage=set_voltage)

##IN def apply_voltage(set_voltage, duration):
#keithley.enable_source()
#CHANGE
rand_num = random.random()
currents_data.append(rand_num)
voltages_data.append(rand_num)
local_currents_data.append(rand_num)
local_voltages_data.append(rand_num)
#TO
currents_data.append(keithley.current[1])
voltages_data.append(keithley.voltage[0])
local_currents_data.append(keithley.current[1])
local_voltages_data.append(keithley.voltage[0])

##IN def stop_measurement():
#keithley.disable_source()

##IN def start_IV():
#configure_keithley('IV', compliance_current=compliance_current_value_IV)

##IN def apply_voltage_IV(set_voltage_IV):
#keithley.enable_source()  # Enable the source before measurement
#current = keithley.current[1]  # Get the current measurement
#DELETE
current = random.random()

##IN def measure_IV(set_voltage_IV, step_vol_IV, step_time_IV, delay_value_IV):
#keithley.source_voltage = curr_voltage_IV
#keithley.source_voltage = 0
#keithley.disable_source()



###DELETE
ALL pass (not in start_pulse)

# %%
import re

def uncomment_line(file_path_read, file_path_write, pattern):
    with open(file_path_read, 'r') as file:
        lines = file.readlines()

    with open(file_path_write, 'w') as file:
        for line in lines:
            stripped_line = line.lstrip()  # Remove leading spaces temporarily
            if stripped_line.startswith('#') and re.search(pattern, stripped_line):
                line = line.replace('#', '', 1)  # Remove only the first '#' (preserving indentation)
            file.write(line)


file_path_read = r'C:\Users\Maciek\Keithley_controller_Agnieszka_Kerr_tracking_working_Gacius.py'
file_path_write = r'C:\Users\Maciek\new_keithley.py'
uncomment_patterns = [r'.* import Keithley 2400.*', r'.*from pymeasure.*', r'.*import pyvisa.*', r'.*rm = pyvisa.*',
                     r'.*keithley_pyvisa.*', r'.*configure_keithley.*', r'.*from pymeasure.*', r'.*keithley..*']

for pattern in uncomment_patterns:
    print(pattern)
    uncomment_line(file_path_read, file_path_write, pattern)
# Out:
# .* import Keithley 2400.*
# #!/usr/bin/env python
#
# # coding: utf-8
#
#
#
# # Keithley 2400 GUI - Software to apply constant voltage
#
#
#
# # Importing libraries + initializing global variables
#
#
#
# # In[1]:
#
#
#
#
#
# import tkinter as tk
#
# from tkinter import font as tkFont
#
# from tkinter import ttk, filedialog, messagebox
#
# from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg
#
# import matplotlib.pyplot as plt
#
# import time as tm
#
# import datetime
#
# import json
#
# import os
#
# import sys
#
# import pyautogui
#
# import pyperclip
#
# import threading
#
# import keyboard
#
# import pygetwindow as gw
#
# import random
#
#
#
# pattern found
# # import Keithley 2400; address 24
#
#  import Keithley 2400; address 24
#
# #from pymeasure.instruments.keithley import Keithley2400
#
# #import pyvisa
#
#
#
# # global variables
#
# keithley = 'test'
#
# fig, ax = plt.subplots()
#
# line, = ax.plot([], [], 'bo-')
#
# ax.set_xlabel('$t$ (s)', fontsize=13)
#
# ...
